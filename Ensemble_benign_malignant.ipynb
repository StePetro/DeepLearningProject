# %% [markdown]
# Author: **Stefano Petrocchi**

# %% [markdown]
# ## Dependencies and Variables:

# %%
import tensorflow as tf
from tensorflow import keras

import numpy as np
import datetime
import os
from tensorflow.keras import layers
from tensorflow.keras import models
from tensorflow.keras.utils import plot_model
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model
from keras.layers.merge import concatenate
from tensorflow.python.framework.ops import disable_eager_execution
from sklearn.preprocessing import Normalizer
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from tensorflow.python.util import deprecation
import pickle


deprecation._PRINT_DEPRECATION_WARNINGS = False

disable_eager_execution() #To execute the gradient

BASE_PATH = "drive/MyDrive/Petrocchi"
MODELS_PATH = BASE_PATH + "/models"
DATA_PATH = BASE_PATH + "/data/"
CHECKPOINT_PATH = BASE_PATH + "/checkpoints"
HISTORY_PATH = BASE_PATH + "/history"

labels_dict = {
  "0": "BASELINE",
  "1": "MASS BENIGN",
  "2": "MASS MALIGNANT",
  "3": "CALCIFICATION BENIGN",
  "4": "CALCIFICATION MALIGNANT"
}

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install -q pyyaml h5py

# %%
# !pip install import_ipynb
# Out:
# Requirement already satisfied: import_ipynb in /usr/local/lib/python3.6/dist-packages (0.1.3)

# %%
# Get util functions
import import_ipynb
import drive.MyDrive.Petrocchi.util.preprocessing as preprocessing
import drive.MyDrive.Petrocchi.util.models as my_models
import drive.MyDrive.Petrocchi.util.visualization as visual
import drive.MyDrive.Petrocchi.util.SVM as svm
# Out:
# importing Jupyter notebook from /content/drive/MyDrive/Petrocchi/util/preprocessing.ipynb
# "load_images_and_lables" function loaded
# "preprocess_normalize_images" function loaded
# "deprocess_image_to_RGB" function loaded
# "deprocess_image" function loaded
# "datagen" class loaded
# "binary_subdivision" function loaded
# importing Jupyter notebook from /content/drive/MyDrive/Petrocchi/util/models.ipynb
# "tiny_net" CNN loaded
# "mammo_net" CNN loaded
# importing Jupyter notebook from /content/drive/MyDrive/Petrocchi/util/visualization.ipynb
# "plot_history" function loaded
# "plot_roc_curve" function loaded
# "plot_confusion_matrix" function loaded
# "generate_pattern" function loaded
# "display_filters_patterns" function loaded
# "display_features_maps" function loaded
# "generate_pattern_RGB" function loaded
# "display_filters_patterns" function loaded
# importing Jupyter notebook from /content/drive/MyDrive/Petrocchi/util/SVM.ipynb
# "create_feature_extractor" function loaded
# "extract_features" function loaded
# "train_svm_classifier" function loaded

# %% [markdown]
# ## Data Loading:

# %%
train_images, train_labels= preprocessing.load_images_and_lables(DATA_PATH + 'train_tensor.npy', DATA_PATH + 'train_labels.npy')
test_images, test_labels= preprocessing.load_images_and_lables(DATA_PATH + 'public_test_tensor.npy', DATA_PATH + 'public_test_labels.npy')

# Class Distribution
plt.hist(train_labels)
plt.title("Train Class Distribution")
plt.show()

unique, counts = np.unique(train_labels, return_counts=True)
plt.pie(counts, labels = ["BASELINE"," BENIGN","MASS MALIGNANT","CALCIFICATION BENIGN","CALCIFICATION MALIGNANT"])
plt.title('Train Class Distribution')
plt.show()

unique, counts = np.unique(test_labels, return_counts=True)
plt.pie(counts, labels = ["BASELINE","MASS BENIGN","MASS MALIGNANT","CALCIFICATION BENIGN","CALCIFICATION MALIGNANT"])
plt.title('Test Class Distribution')
plt.show()

# Plot an example
img_index = 5
plt.imshow(train_images[img_index,:,:],cmap = 'gray')
plt.title(labels_dict[str(train_labels[img_index])])
plt.show()

# %% [markdown]
# ## General Data Preprocessing:

# %% [markdown]
# Normalize and convert to RGB:

# %%
# I also need to convert back to numpy array using eval()
tf.compat.v1.disable_eager_execution()
sess = tf.compat.v1.Session()
with sess.as_default():
  print(train_images.shape)
  pp_train_images = tf.image.grayscale_to_rgb(tf.convert_to_tensor(preprocessing.preprocess_normalize_images(train_images, train_images.mean(), train_images.std()))).eval()
  print(pp_train_images.shape)

  print(test_images.shape)
  pp_test_images = tf.image.grayscale_to_rgb(tf.convert_to_tensor(preprocessing.preprocess_normalize_images(test_images, train_images.mean(), train_images.std()))).eval()
  print(pp_test_images.shape)
# Out:
# (5352, 150, 150)
# (5352, 150, 150, 3)
# (672, 150, 150)
# (672, 150, 150, 3)

# %% [markdown]
# Abnormalities-Baselines subdivision

# %%
# For reference
idx = 1
plt.imshow(preprocessing.deprocess_image_to_RGB(pp_train_images[idx]))
plt.title(labels_dict[str(train_labels[idx])])
plt.show()
plt.imshow(preprocessing.deprocess_image_to_RGB(pp_train_images[idx-1]))
plt.title(labels_dict[str(train_labels[idx-1])])
plt.show()

# %%
#Train
train_abnormalities = pp_train_images[1::2]
train_abnormalities_labels = train_labels[1::2]
train_baselines = pp_train_images[::2]

#Test
test_abnormalities = pp_test_images[1::2]
test_abnormalities_labels = test_labels[1::2]
test_baselines = pp_test_images[::2]

# Confirms that subdivision is good
idx = 0
plt.imshow(preprocessing.deprocess_image_to_RGB(train_abnormalities[idx]))
plt.title(labels_dict[str(train_abnormalities_labels[idx])])
plt.show()
plt.imshow(preprocessing.deprocess_image_to_RGB(train_baselines[idx]))
plt.title("Relative Baseline")
plt.show()

# %% [markdown]
# Test Augmentation:

# %%
# Test: show random augmented image
for batch in preprocessing.datagen.flow([train_abnormalities[0:1],train_baselines[0:1]], train_abnormalities_labels[0:1], batch_size=1):
    plt.title(labels_dict[str(batch[1][0])])
    print(batch[0][0].shape)
    plt.imshow(preprocessing.deprocess_image_to_RGB(batch[0][0][0][:,:,:]))
    plt.show()
    plt.imshow(preprocessing.deprocess_image_to_RGB(batch[0][1][0][:,:,:]))
    plt.title("Relative Baseline")
    plt.show()
    break
# Out:
# (1, 150, 150, 3)

# %% [markdown]
# Binary subdivision:

# %%
# 0: BENIGN, 1: MALIGNANT
bm_train_images, bm_train_labels, bm_test_images, bm_test_labels = preprocessing.binary_subdivision( 
    [1,3], [2,4], train_abnormalities, train_abnormalities_labels, test_abnormalities, test_abnormalities_labels)  

print("Benigns Malignants")
print(bm_train_images.shape)
print(bm_train_labels.shape)
print(bm_test_images.shape)
print(bm_test_labels.shape)

# Class Distribution
unique, counts = np.unique(bm_train_labels, return_counts=True)
plt.pie(counts, labels = ["BENIGN","MALIGNANT"])
plt.title('Train Class Distribution')
plt.show()

unique, counts = np.unique(bm_test_labels, return_counts=True)
plt.pie(counts, labels = ["BENIGN","MALIGNANT"])
plt.title('Test Class Distribution')
plt.show()
# Out:
# Benigns Malignants
# (2676, 150, 150, 3)
# (2676,)
# (336, 150, 150, 3)
# (336,)

# %% [markdown]
# # Ensemble Mass VS Calcification Classifiers

# %% [markdown]
# ### Split:

# %%
bm_train_images, bm_train_labels, bm_val_images, bm_val_labels, bm_val_baselines, bm_train_baselines = preprocessing.split_train_validation_baseline(bm_train_images, bm_train_labels, 0.2, train_baselines)

print(bm_train_images.shape)
print(bm_train_labels.shape)
print(bm_val_images.shape)
print(bm_val_labels.shape)
print(bm_train_baselines.shape)
print(bm_val_baselines.shape)

# Class Distribution
unique, counts = np.unique(bm_train_labels, return_counts=True)
plt.pie(counts, labels = ["BENIGN","MALIGNANT"])
plt.title('Train Class Distribution')
plt.show()

unique, counts = np.unique(bm_val_labels, return_counts=True)
plt.pie(counts, labels = ["BENIGN","MALIGNANT"])
plt.title('Validation Class Distribution')
plt.show()

idx = 22
plt.imshow(preprocessing.deprocess_image_to_RGB(bm_val_images[idx]))
plt.title("Abnormality")
plt.show()
plt.imshow(preprocessing.deprocess_image_to_RGB(bm_val_baselines[idx]))
plt.title("Relative Baseline")
plt.show()
# Out:
# (2140, 150, 150, 3)
# (2140,)
# (536, 150, 150, 3)
# (536,)
# (2140, 150, 150, 3)
# (536, 150, 150, 3)

# %% [markdown]
# ###General Parameters for training:

# %%
# Training parameters that are good for all models

# From ISMMS paper 32
# From Girona & Manchester paper 128
BATCH_SIZE = 107 # to have even batches 
STEPS_PER_EPOCH = len(bm_train_images) // BATCH_SIZE # 20
OPTIMIZER = tf.keras.optimizers.Adam(learning_rate=0.001) 
LOSS = 'binary_crossentropy'

# Large values ensures to not lose better weights 
MAX_EPOCHS = 1000 
PATIENCE = 50 

# Automatically restore best weights after early stopping
es_callback = tf.keras.callbacks.EarlyStopping(monitor = 'val_loss', patience = PATIENCE, restore_best_weights = True)

# %% [markdown]
# ### Load Previous Models

# %%
# !!!!To avoid graph errors!!!!
tf.compat.v1.reset_default_graph()
models_acc = np.asarray([])
train_input = []
validate_input = []
test_input = []
test_input_for_weghted = []

# %%
ResNet50_TL_bm = keras.models.load_model(os.path.join(MODELS_PATH,'ResNet50_TL_bm.h5'))
val_loss, val_acc = ResNet50_TL_bm.evaluate(bm_val_images, bm_val_labels)
print(f"Accuracy on validation set: {round(val_acc*100, 2)}% \nLoss on validation set: {round(val_loss,4)}")
models_acc = np.append(models_acc, val_acc)
train_input.append(bm_train_images)
validate_input.append(bm_val_images)
test_input.append(bm_test_images)
test_input_for_weghted.append(bm_test_images)
# Out:
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:2325: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# Accuracy on validation set: 64.55%
# Loss on validation set: 0.5865

# %%
VGG16_FT_bm = keras.models.load_model(os.path.join(MODELS_PATH,'VGG16_FT_bm.h5'))
val_loss, val_acc = VGG16_FT_bm.evaluate(bm_val_images, bm_val_labels)
print(f"Accuracy on validation set: {round(val_acc*100, 2)}% \nLoss on validation set: {round(val_loss,4)}")
models_acc = np.append(models_acc, val_acc)
train_input.append(bm_train_images)
validate_input.append(bm_val_images)
test_input.append(bm_test_images)
test_input_for_weghted.append(bm_test_images)
# Out:
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:2325: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# Accuracy on validation set: 75.93%
# Loss on validation set: 0.5374

# %%
InceptionV3_FT_bm = keras.models.load_model(os.path.join(MODELS_PATH,'InceptionV3_FT_bm.h5'))
val_loss, val_acc = InceptionV3_FT_bm.evaluate(bm_val_images, bm_val_labels)
print(f"Accuracy on validation set: {round(val_acc*100, 2)}% \nLoss on validation set: {round(val_loss,4)}")
models_acc = np.append(models_acc, val_acc)
train_input.append(bm_train_images)
validate_input.append(bm_val_images)
test_input.append(bm_test_images)
test_input_for_weghted.append(bm_test_images)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:2325: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# Accuracy on validation set: 66.42%
# Loss on validation set: 0.6025

# %%
siamese_bm_difference = keras.models.load_model(os.path.join(MODELS_PATH,'siamese_bm_difference.h5'))
val_loss, val_acc = siamese_bm_difference.evaluate([bm_val_images, bm_val_baselines], bm_val_labels)
print(f"Accuracy on validation set: {round(val_acc*100, 2)}% \nLoss on validation set: {round(val_loss,4)}")
models_acc = np.append(models_acc, val_acc)
train_input.append(bm_train_images)
train_input.append(bm_train_baselines)
validate_input.append(bm_val_images)
validate_input.append(bm_val_baselines)
test_input.append(bm_test_images)
test_input.append(test_baselines)
test_input_for_weghted.append([bm_test_images,test_baselines])
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:2325: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# Accuracy on validation set: 68.47%
# Loss on validation set: 0.5852

# %%
siamese_bm_concat = keras.models.load_model(os.path.join(MODELS_PATH,'siamese_bm_concat.h5'))
val_loss, val_acc = siamese_bm_concat.evaluate([bm_val_images, bm_val_baselines], bm_val_labels)
print(f"Accuracy on validation set: {round(val_acc*100, 2)}% \nLoss on validation set: {round(val_loss,4)}")
models_acc = np.append(models_acc, val_acc)
train_input.append(bm_train_images)
train_input.append(bm_train_baselines)
validate_input.append(bm_val_images)
validate_input.append(bm_val_baselines)
test_input.append(bm_test_images)
test_input.append(test_baselines)
test_input_for_weghted.append([bm_test_images,test_baselines])
# Out:
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:2325: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# Accuracy on validation set: 70.34%
# Loss on validation set: 0.5531

# %%
members = np.asarray([ResNet50_TL_bm, VGG16_FT_bm, InceptionV3_FT_bm, siamese_bm_difference, siamese_bm_concat])

# %% [markdown]
# ##Weighted Ensemble

# %%
def ensemble_weighted_prediction(models, models_acc, inputs):
  '''
  Predict inputs class as weighted sum of models predictions by their total accuracy
  '''
  softmax_array = np.exp(models_acc)/sum(np.exp(models_acc))
  ensemble_prediction = 0
  for model, weight, input in zip(models, softmax_array,inputs):
    ensemble_prediction += model.predict(input)*weight
  return ensemble_prediction

# %%
idx = [0,1,2,3,4]

# %%
test_acc = accuracy_score(bm_test_labels, ensemble_weighted_prediction(members[idx], models_acc[idx],test_input_for_weghted).round())
print(f"Accuracy on test set: {round(test_acc*100, 2)}%")
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:2325: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# Accuracy on test set: 72.02%

# %% [markdown]
# ##Stacking Ensemble

# %%
# update all layers in all models to not be trainable
for i in range(len(members)):
	model = members[i]
	for layer in model.layers:
		# make not trainable
		layer.trainable = False
		# rename to avoid 'unique layer name' issue
		layer._name = 'ensemble_' + str(i+1) + '_' + layer.name

# %%
# define multi-headed input
ensemble_visible = [model.input for model in members]
# concatenate merge output from each model
ensemble_outputs = [model.output for model in members]
merge = concatenate(ensemble_outputs)
fc1 = layers.Dense(5, activation='relu', name = "fully_connected_1")(merge)
fc2 = layers.Dense(5, activation='relu', name = "fully_connected_2")(fc1)
output = layers.Dense(1, activation='sigmoid', name = "fully_connected_out")(fc2)
ensemle_bm = Model(inputs=ensemble_visible, outputs=output)

ensemle_bm.compile(loss=LOSS,
              optimizer = OPTIMIZER,                   
              metrics=['accuracy'])

# Save weights when model improves (In case of disconnection)
cp_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=CHECKPOINT_PATH + "/ensemle_bm/checkpoint.ckpt", 
    verbose=1, 
    save_weights_only=True,
    save_best_only=True ) 

# plot graph of ensemble
ensemle_bm.summary()
plot_model(ensemle_bm, show_shapes=True)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# resnet50_input (InputLayer)     [(None, 150, 150, 3) 0
# __________________________________________________________________________________________________
# vgg16_input (InputLayer)        [(None, 150, 150, 3) 0
# __________________________________________________________________________________________________
# inception_v3_input (InputLayer) [(None, 150, 150, 3) 0
# __________________________________________________________________________________________________
# ensemble_4_left_input (InputLay [(None, 150, 150, 3) 0
# __________________________________________________________________________________________________
# ensemble_4_right_input (InputLa [(None, 150, 150, 3) 0
# __________________________________________________________________________________________________
# ensemble_5_left_input (InputLay [(None, 150, 150, 3) 0
# __________________________________________________________________________________________________
# ensemble_5_right_input (InputLa [(None, 150, 150, 3) 0
# __________________________________________________________________________________________________
# ensemble_1_resnet50 (Functional (None, 5, 5, 2048)   23587712    resnet50_input[0][0]
# __________________________________________________________________________________________________
# ensemble_2_vgg16 (Functional)   (None, 4, 4, 512)    14714688    vgg16_input[0][0]
# __________________________________________________________________________________________________
# ensemble_3_inception_v3 (Functi (None, 3, 3, 2048)   21802784    inception_v3_input[0][0]
# __________________________________________________________________________________________________
# ensemble_4_VGG16_TL_mass_calcif (None, 8192)         14714688    ensemble_4_left_input[0][0]
#                                                                  ensemble_4_right_input[0][0]
# __________________________________________________________________________________________________
# ensemble_5_VGG16_TL_mass_calcif (None, 8192)         14714688    ensemble_5_left_input[0][0]
#                                                                  ensemble_5_right_input[0][0]
# __________________________________________________________________________________________________
# ensemble_1_flatten (Flatten)    (None, 51200)        0           ensemble_1_resnet50[0][0]
# __________________________________________________________________________________________________
# ensemble_2_flatten (Flatten)    (None, 8192)         0           ensemble_2_vgg16[0][0]
# __________________________________________________________________________________________________
# ensemble_3_flatten (Flatten)    (None, 18432)        0           ensemble_3_inception_v3[0][0]
# __________________________________________________________________________________________________
# ensemble_4_lambda (Lambda)      (None, 8192)         0           ensemble_4_VGG16_TL_mass_calcific
#                                                                  ensemble_4_VGG16_TL_mass_calcific
# __________________________________________________________________________________________________
# ensemble_5_concatenate (Concate (None, 16384)        0           ensemble_5_VGG16_TL_mass_calcific
#                                                                  ensemble_5_VGG16_TL_mass_calcific
# __________________________________________________________________________________________________
# ensemble_1_dropout_6 (Dropout)  (None, 51200)        0           ensemble_1_flatten[0][0]
# __________________________________________________________________________________________________
# ensemble_2_dropout_9 (Dropout)  (None, 8192)         0           ensemble_2_flatten[0][0]
# __________________________________________________________________________________________________
# ensemble_3_dropout (Dropout)    (None, 18432)        0           ensemble_3_flatten[0][0]
# __________________________________________________________________________________________________
# ensemble_4_dropout_1 (Dropout)  (None, 8192)         0           ensemble_4_lambda[0][0]
# __________________________________________________________________________________________________
# ensemble_5_dropout_1 (Dropout)  (None, 16384)        0           ensemble_5_concatenate[0][0]
# __________________________________________________________________________________________________
# ensemble_1_fully_connected_0 (D (None, 512)          26214912    ensemble_1_dropout_6[0][0]
# __________________________________________________________________________________________________
# ensemble_2_fully_connected_0 (D (None, 4096)         33558528    ensemble_2_dropout_9[0][0]
# __________________________________________________________________________________________________
# ensemble_3_fully_connected_0 (D (None, 2048)         37750784    ensemble_3_dropout[0][0]
# __________________________________________________________________________________________________
# ensemble_4_fully_connected_1 (D (None, 4096)         33558528    ensemble_4_dropout_1[0][0]
# __________________________________________________________________________________________________
# ensemble_5_fully_connected_1 (D (None, 4096)         67112960    ensemble_5_dropout_1[0][0]
# __________________________________________________________________________________________________
# ensemble_1_dropout_7 (Dropout)  (None, 512)          0           ensemble_1_fully_connected_0[0][0
# __________________________________________________________________________________________________
# ensemble_2_dropout_10 (Dropout) (None, 4096)         0           ensemble_2_fully_connected_0[0][0
# __________________________________________________________________________________________________
# ensemble_3_dropout_1 (Dropout)  (None, 2048)         0           ensemble_3_fully_connected_0[0][0
# __________________________________________________________________________________________________
# ensemble_4_dropout_2 (Dropout)  (None, 4096)         0           ensemble_4_fully_connected_1[0][0
# __________________________________________________________________________________________________
# ensemble_5_dropout_2 (Dropout)  (None, 4096)         0           ensemble_5_fully_connected_1[0][0
# __________________________________________________________________________________________________
# ensemble_1_fully_connected_1 (D (None, 512)          262656      ensemble_1_dropout_7[0][0]
# __________________________________________________________________________________________________
# ensemble_2_fully_connected_1 (D (None, 4096)         16781312    ensemble_2_dropout_10[0][0]
# __________________________________________________________________________________________________
# ensemble_3_fully_connected_1 (D (None, 2048)         4196352     ensemble_3_dropout_1[0][0]
# __________________________________________________________________________________________________
# ensemble_4_fully_connected_2 (D (None, 4096)         16781312    ensemble_4_dropout_2[0][0]
# __________________________________________________________________________________________________
# ensemble_5_fully_connected_2 (D (None, 4096)         16781312    ensemble_5_dropout_2[0][0]
# __________________________________________________________________________________________________
# ensemble_1_dropout_8 (Dropout)  (None, 512)          0           ensemble_1_fully_connected_1[0][0
# __________________________________________________________________________________________________
# ensemble_2_dropout_11 (Dropout) (None, 4096)         0           ensemble_2_fully_connected_1[0][0
# __________________________________________________________________________________________________
# ensemble_3_dropout_2 (Dropout)  (None, 2048)         0           ensemble_3_fully_connected_1[0][0
# __________________________________________________________________________________________________
# ensemble_4_dropout_3 (Dropout)  (None, 4096)         0           ensemble_4_fully_connected_2[0][0
# __________________________________________________________________________________________________
# ensemble_5_dropout_3 (Dropout)  (None, 4096)         0           ensemble_5_fully_connected_2[0][0
# __________________________________________________________________________________________________
# ensemble_1_fully_connected_out  (None, 1)            513         ensemble_1_dropout_8[0][0]
# __________________________________________________________________________________________________
# ensemble_2_fully_connected_out  (None, 1)            4097        ensemble_2_dropout_11[0][0]
# __________________________________________________________________________________________________
# ensemble_3_fully_connected_out  (None, 1)            2049        ensemble_3_dropout_2[0][0]
# __________________________________________________________________________________________________
# ensemble_4_fully_connected_out  (None, 1)            4097        ensemble_4_dropout_3[0][0]
# __________________________________________________________________________________________________
# ensemble_5_fully_connected_out  (None, 1)            4097        ensemble_5_dropout_3[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 5)            0           ensemble_1_fully_connected_out[0]
#                                                                  ensemble_2_fully_connected_out[0]
#                                                                  ensemble_3_fully_connected_out[0]
#                                                                  ensemble_4_fully_connected_out[0]
#                                                                  ensemble_5_fully_connected_out[0]
# __________________________________________________________________________________________________
# fully_connected_1 (Dense)       (None, 5)            30          concatenate[0][0]
# __________________________________________________________________________________________________
# fully_connected_2 (Dense)       (None, 5)            30          fully_connected_1[0][0]
# __________________________________________________________________________________________________
# fully_connected_out (Dense)     (None, 1)            6           fully_connected_2[0][0]
# ==================================================================================================
# Total params: 342,548,135
# Trainable params: 66
# Non-trainable params: 342,548,069
# __________________________________________________________________________________________________

# %% [markdown]
# Training:

# %%
ensemle_bm_history = ensemle_bm.fit(train_input, bm_train_labels, epochs=MAX_EPOCHS, batch_size=BATCH_SIZE, validation_data = (validate_input, bm_val_labels), callbacks=[es_callback])
# Out:
# Train on 2140 samples, validate on 536 samples
# Epoch 1/1000
# 2140/2140 [==============================] - ETA: 0s - loss: 0.6718 - accuracy: 0.6327
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:2325: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 2140/2140 [==============================] - 46s 22ms/sample - loss: 0.6718 - accuracy: 0.6327 - val_loss: 0.6695 - val_accuracy: 0.6586
# Epoch 2/1000
# 2140/2140 [==============================] - 35s 16ms/sample - loss: 0.6590 - accuracy: 0.7065 - val_loss: 0.6588 - val_accuracy: 0.6959
# Epoch 3/1000
# 2140/2140 [==============================] - 35s 16ms/sample - loss: 0.6430 - accuracy: 0.7575 - val_loss: 0.6474 - val_accuracy: 0.7146
# Epoch 4/1000
# 2140/2140 [==============================] - 36s 17ms/sample - loss: 0.6277 - accuracy: 0.7771 - val_loss: 0.6352 - val_accuracy: 0.7201
# Epoch 5/1000
# 2140/2140 [==============================] - 36s 17ms/sample - loss: 0.6134 - accuracy: 0.7748 - val_loss: 0.6235 - val_accuracy: 0.7257
# Epoch 6/1000
# 2140/2140 [==============================] - 36s 17ms/sample - loss: 0.5983 - accuracy: 0.7939 - val_loss: 0.6115 - val_accuracy: 0.7295
# Epoch 7/1000
# 2140/2140 [==============================] - 36s 17ms/sample - loss: 0.5776 - accuracy: 0.8028 - val_loss: 0.5990 - val_accuracy: 0.7407
# Epoch 8/1000
# 2140/2140 [==============================] - 36s 17ms/sample - loss: 0.5612 - accuracy: 0.8075 - val_loss: 0.5869 - val_accuracy: 0.7463
# Epoch 9/1000
# 2140/2140 [==============================] - 36s 17ms/sample - loss: 0.5425 - accuracy: 0.8126 - val_loss: 0.5746 - val_accuracy: 0.7575
# Epoch 10/1000
# 2140/2140 [==============================] - 36s 17ms/sample - loss: 0.5206 - accuracy: 0.8201 - val_loss: 0.5628 - val_accuracy: 0.7556
# Epoch 11/1000
# 2140/2140 [==============================] - 36s 17ms/sample - loss: 0.5008 - accuracy: 0.8266 - val_loss: 0.5521 - val_accuracy: 0.7500
# Epoch 12/1000
# 2140/2140 [==============================] - 36s 17ms/sample - loss: 0.4831 - accuracy: 0.8336 - val_loss: 0.5429 - val_accuracy: 0.7481
# Epoch 13/1000
# 2140/2140 [==============================] - 36s 17ms/sample - loss: 0.4620 - accuracy: 0.8449 - val_loss: 0.5347 - val_accuracy: 0.7500
# Epoch 14/1000
# 2140/2140 [==============================] - 36s 17ms/sample - loss: 0.4492 - accuracy: 0.8383 - val_loss: 0.5271 - val_accuracy: 0.7500
# Epoch 15/1000
# 2140/2140 [==============================] - 36s 17ms/sample - loss: 0.4332 - accuracy: 0.8374 - val_loss: 0.5224 - val_accuracy: 0.7537
# Epoch 16/1000
# 2140/2140 [==============================] - 36s 17ms/sample - loss: 0.4198 - accuracy: 0.8374 - val_loss: 0.5173 - val_accuracy: 0.7500
# Epoch 17/1000
# 2140/2140 [==============================] - 36s 17ms/sample - loss: 0.4138 - accuracy: 0.8388 - val_loss: 0.5155 - val_accuracy: 0.7500
# Epoch 18/1000
# 2140/2140 [==============================] - 36s 17ms/sample - loss: 0.3941 - accuracy: 0.8458 - val_loss: 0.5146 - val_accuracy: 0.7481
# Epoch 19/1000
# 2140/2140 [==============================] - 36s 17ms/sample - loss: 0.3862 - accuracy: 0.8449 - val_loss: 0.5120 - val_accuracy: 0.7463
# Epoch 20/1000
# 2140/2140 [==============================] - 36s 17ms/sample - loss: 0.3768 - accuracy: 0.8453 - val_loss: 0.5151 - val_accuracy: 0.7481
# Epoch 21/1000
# 2140/2140 [==============================] - 36s 17ms/sample - loss: 0.3731 - accuracy: 0.8444 - val_loss: 0.5143 - val_accuracy: 0.7500
# Epoch 22/1000
# 2140/2140 [==============================] - 36s 17ms/sample - loss: 0.3649 - accuracy: 0.8486 - val_loss: 0.5161 - val_accuracy: 0.7500
# Epoch 23/1000
# 2140/2140 [==============================] - 36s 17ms/sample - loss: 0.3598 - accuracy: 0.8477 - val_loss: 0.5185 - val_accuracy: 0.7500
# Epoch 24/1000
# 2140/2140 [==============================] - 36s 17ms/sample - loss: 0.3551 - accuracy: 0.8509 - val_loss: 0.5188 - val_accuracy: 0.7481
# Epoch 25/1000
# 2140/2140 [==============================] - 36s 17ms/sample - loss: 0.3472 - accuracy: 0.8523 - val_loss: 0.5220 - val_accuracy: 0.7519
# Epoch 26/1000
# 2140/2140 [==============================] - 36s 17ms/sample - loss: 0.3420 - accuracy: 0.8570 - val_loss: 0.5237 - val_accuracy: 0.7481
# Epoch 27/1000
# 2140/2140 [==============================] - 36s 17ms/sample - loss: 0.3429 - accuracy: 0.8500 - val_loss: 0.5255 - val_accuracy: 0.7500
# Epoch 28/1000
# 2140/2140 [==============================] - 36s 17ms/sample - loss: 0.3398 - accuracy: 0.8537 - val_loss: 0.5291 - val_accuracy: 0.7500
# Epoch 29/1000
# 2140/2140 [==============================] - 36s 17ms/sample - loss: 0.3396 - accuracy: 0.8533 - val_loss: 0.5294 - val_accuracy: 0.7481
# Epoch 30/1000
# 2140/2140 [==============================] - 36s 17ms/sample - loss: 0.3359 - accuracy: 0.8542 - val_loss: 0.5316 - val_accuracy: 0.7500
# Epoch 31/1000
# 2140/2140 [==============================] - 36s 17ms/sample - loss: 0.3351 - accuracy: 0.8547 - val_loss: 0.5339 - val_accuracy: 0.7500
# Epoch 32/1000
# 2140/2140 [==============================] - 36s 17ms/sample - loss: 0.3290 - accuracy: 0.8612 - val_loss: 0.5361 - val_accuracy: 0.7500
# Epoch 33/1000
# 2140/2140 [==============================] - 36s 17ms/sample - loss: 0.3250 - accuracy: 0.8519 - val_loss: 0.5382 - val_accuracy: 0.7500
# Epoch 34/1000
# 2140/2140 [==============================] - 36s 17ms/sample - loss: 0.3233 - accuracy: 0.8570 - val_loss: 0.5396 - val_accuracy: 0.7481
# Epoch 35/1000
# 2140/2140 [==============================] - 36s 17ms/sample - loss: 0.3278 - accuracy: 0.8519 - val_loss: 0.5409 - val_accuracy: 0.7481
# Epoch 36/1000
# 2140/2140 [==============================] - 36s 17ms/sample - loss: 0.3298 - accuracy: 0.8528 - val_loss: 0.5424 - val_accuracy: 0.7481
# Epoch 37/1000
# 2140/2140 [==============================] - 36s 17ms/sample - loss: 0.3171 - accuracy: 0.8598 - val_loss: 0.5425 - val_accuracy: 0.7463
# Epoch 38/1000
# 2140/2140 [==============================] - 36s 17ms/sample - loss: 0.3196 - accuracy: 0.8551 - val_loss: 0.5458 - val_accuracy: 0.7463
# Epoch 39/1000
# 2140/2140 [==============================] - 36s 17ms/sample - loss: 0.3150 - accuracy: 0.8687 - val_loss: 0.5461 - val_accuracy: 0.7444
# Epoch 40/1000
# 2140/2140 [==============================] - 36s 17ms/sample - loss: 0.3162 - accuracy: 0.8645 - val_loss: 0.5480 - val_accuracy: 0.7444
# Epoch 41/1000
# 2140/2140 [==============================] - 36s 17ms/sample - loss: 0.3126 - accuracy: 0.8682 - val_loss: 0.5495 - val_accuracy: 0.7444
# Epoch 42/1000
# 2140/2140 [==============================] - 36s 17ms/sample - loss: 0.3141 - accuracy: 0.8650 - val_loss: 0.5512 - val_accuracy: 0.7481
# Epoch 43/1000
# 2140/2140 [==============================] - 36s 17ms/sample - loss: 0.3120 - accuracy: 0.8561 - val_loss: 0.5513 - val_accuracy: 0.7463
# Epoch 44/1000
# 2140/2140 [==============================] - 36s 17ms/sample - loss: 0.3129 - accuracy: 0.8621 - val_loss: 0.5535 - val_accuracy: 0.7463
# Epoch 45/1000
# 2140/2140 [==============================] - 36s 17ms/sample - loss: 0.3127 - accuracy: 0.8654 - val_loss: 0.5539 - val_accuracy: 0.7481
# Epoch 46/1000
# 2140/2140 [==============================] - 36s 17ms/sample - loss: 0.3132 - accuracy: 0.8664 - val_loss: 0.5542 - val_accuracy: 0.7444
# Epoch 47/1000
# 2140/2140 [==============================] - 36s 17ms/sample - loss: 0.3128 - accuracy: 0.8626 - val_loss: 0.5555 - val_accuracy: 0.7481
# Epoch 48/1000
# 2140/2140 [==============================] - 36s 17ms/sample - loss: 0.3066 - accuracy: 0.8654 - val_loss: 0.5570 - val_accuracy: 0.7463
# Epoch 49/1000
# 2140/2140 [==============================] - 36s 17ms/sample - loss: 0.3096 - accuracy: 0.8664 - val_loss: 0.5568 - val_accuracy: 0.7481
# Epoch 50/1000
# 2140/2140 [==============================] - 36s 17ms/sample - loss: 0.3103 - accuracy: 0.8617 - val_loss: 0.5594 - val_accuracy: 0.7463
# Epoch 51/1000
# 2140/2140 [==============================] - 36s 17ms/sample - loss: 0.3162 - accuracy: 0.8617 - val_loss: 0.5577 - val_accuracy: 0.7463
# Epoch 52/1000
# 2140/2140 [==============================] - 36s 17ms/sample - loss: 0.3035 - accuracy: 0.8692 - val_loss: 0.5589 - val_accuracy: 0.7425
# Epoch 53/1000
# 2140/2140 [==============================] - 36s 17ms/sample - loss: 0.3070 - accuracy: 0.8612 - val_loss: 0.5601 - val_accuracy: 0.7444
# Epoch 54/1000
# 2140/2140 [==============================] - 36s 17ms/sample - loss: 0.3046 - accuracy: 0.8659 - val_loss: 0.5610 - val_accuracy: 0.7425
# Epoch 55/1000
# 2140/2140 [==============================] - 36s 17ms/sample - loss: 0.3031 - accuracy: 0.8640 - val_loss: 0.5623 - val_accuracy: 0.7444
# Epoch 56/1000
# 2140/2140 [==============================] - 36s 17ms/sample - loss: 0.3088 - accuracy: 0.8636 - val_loss: 0.5615 - val_accuracy: 0.7425
# Epoch 57/1000
# 2140/2140 [==============================] - 36s 17ms/sample - loss: 0.3050 - accuracy: 0.8687 - val_loss: 0.5621 - val_accuracy: 0.7425
# Epoch 58/1000
# 2140/2140 [==============================] - 36s 17ms/sample - loss: 0.3096 - accuracy: 0.8687 - val_loss: 0.5638 - val_accuracy: 0.7463
# Epoch 59/1000
# 2140/2140 [==============================] - 36s 17ms/sample - loss: 0.3020 - accuracy: 0.8659 - val_loss: 0.5628 - val_accuracy: 0.7407
# Epoch 60/1000
# 2140/2140 [==============================] - 36s 17ms/sample - loss: 0.3020 - accuracy: 0.8636 - val_loss: 0.5637 - val_accuracy: 0.7425
# Epoch 61/1000
# 2140/2140 [==============================] - 36s 17ms/sample - loss: 0.2995 - accuracy: 0.8673 - val_loss: 0.5644 - val_accuracy: 0.7407
# Epoch 62/1000
# 2140/2140 [==============================] - 36s 17ms/sample - loss: 0.2959 - accuracy: 0.8724 - val_loss: 0.5659 - val_accuracy: 0.7425
# Epoch 63/1000
# 2140/2140 [==============================] - 36s 17ms/sample - loss: 0.3044 - accuracy: 0.8682 - val_loss: 0.5670 - val_accuracy: 0.7407
# Epoch 64/1000
# 2140/2140 [==============================] - 36s 17ms/sample - loss: 0.3086 - accuracy: 0.8631 - val_loss: 0.5661 - val_accuracy: 0.7407
# Epoch 65/1000
# 2140/2140 [==============================] - 36s 17ms/sample - loss: 0.3023 - accuracy: 0.8724 - val_loss: 0.5662 - val_accuracy: 0.7407
# Epoch 66/1000
# 2140/2140 [==============================] - 36s 17ms/sample - loss: 0.3010 - accuracy: 0.8720 - val_loss: 0.5670 - val_accuracy: 0.7388
# Epoch 67/1000
# 2140/2140 [==============================] - 36s 17ms/sample - loss: 0.3006 - accuracy: 0.8678 - val_loss: 0.5672 - val_accuracy: 0.7407
# Epoch 68/1000
# 2140/2140 [==============================] - 36s 17ms/sample - loss: 0.2946 - accuracy: 0.8771 - val_loss: 0.5682 - val_accuracy: 0.7388
# Epoch 69/1000
# 2140/2140 [==============================] - 39s 18ms/sample - loss: 0.3030 - accuracy: 0.8678 - val_loss: 0.5678 - val_accuracy: 0.7388

# %%
# Save and load history
with open(HISTORY_PATH + '/ensemle_bm_history', 'wb') as file_pi:
        pickle.dump(ensemle_bm_history.history, file_pi)

ensemle_bm_history = pickle.load(open(HISTORY_PATH + '/ensemle_bm_history', "rb"))

visual.plot_history(ensemle_bm_history)

# %%
train_loss, train_acc = ensemle_bm.evaluate(train_input, bm_train_labels)
print(f"Accuracy on train set: {round(train_acc*100, 2)}% \nLoss on train set: {round(train_loss,4)}")
val_loss, val_acc = ensemle_bm.evaluate(validate_input, bm_val_labels)
print(f"Accuracy on validation set: {round(val_acc*100, 2)}% \nLoss on validation set: {round(val_loss,4)}")
test_loss, test_acc = ensemle_bm.evaluate(test_input, bm_test_labels)
print(f"Accuracy on test set: {round(test_acc*100, 2)}% \nLoss on test set: {round(test_loss,4)}")
# Out:
# Accuracy on train set: 85.09%
# Loss on train set: 0.3669
# Accuracy on validation set: 74.63%
# Loss on validation set: 0.512
# Accuracy on test set: 70.54%
# Loss on test set: 0.5887

# %% [markdown]
# Load best weights and save:

# %%
# If disconnection occur best weights so far are restored 

#best = tf.train.latest_checkpoint(CHECKPOINT_PATH + "/ensemle_bm/")
#ensemle_bm.load_weights(best)

# %%
if not os.path.exists(MODELS_PATH):
  os.makedirs(MODELS_PATH)
ensemle_bm.save(os.path.join(MODELS_PATH,'ensemle_bm.h5'))

# %% [markdown]
# # Compare Results

# %% [markdown]
# ##Scoring:

# %%
# Weighted Ensemble
test_acc = accuracy_score(bm_test_labels, ensemble_weighted_prediction(members[idx], models_acc[idx],test_input_for_weghted).round())
print(f"Accuracy on test set: {round(test_acc*100, 2)}%")

ensemble_weighted_predictions = ensemble_weighted_prediction(members[idx], models_acc[idx],test_input_for_weghted)
binary_ensemble_weighted_test_predictions = ensemble_weighted_predictions.round()
visual.plot_confusion_matrix(bm_test_labels, binary_ensemble_weighted_test_predictions, ["BENIGN", "MALIGNANT"])
# Out:
# Accuracy on test set: 72.02%

# %%
# Stacking Ensemble
test_loss, test_acc = ensemle_bm.evaluate(test_input, bm_test_labels)
print(f"Accuracy on test set: {round(test_acc*100, 2)}% \nLoss on test set: {round(test_loss,4)}")

ensemle_bm_test_predictions = ensemle_bm.predict(test_input)
binary_ensemle_bm_test_predictions = ensemle_bm_test_predictions.round()
visual.plot_confusion_matrix(bm_test_labels, binary_ensemle_bm_test_predictions, ["BENIGN", "MALIGNANT"])
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:2325: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# Accuracy on test set: 70.54%
# Loss on test set: 0.5887

# %%
# ROC
models_predictions = [ensemle_bm_test_predictions,
                      ensemble_weighted_predictions]

visual.plot_roc_curve(bm_test_labels, models_predictions, ["Weighted Ensemble", "Stacking Ensemble"])

# %% [markdown]
# Author: **Stefano Petrocchi**
