# %% [markdown]
# Author: **Stefano Petrocchi**

# %% [markdown]
# ## Dependencies and Variables:

# %%
import tensorflow as tf
from tensorflow import keras

import numpy as np
import datetime
import os
from tensorflow.keras import layers
from tensorflow.keras import models
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model
from tensorflow.python.framework.ops import disable_eager_execution
from sklearn.preprocessing import Normalizer
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from tensorflow.python.util import deprecation
from tensorflow.keras.utils import plot_model
import pickle


deprecation._PRINT_DEPRECATION_WARNINGS = False

disable_eager_execution() #To execute the gradient

BASE_PATH = "drive/MyDrive/Petrocchi"
MODELS_PATH = BASE_PATH + "/models"
DATA_PATH = BASE_PATH + "/data/"
CHECKPOINT_PATH = BASE_PATH + "/checkpoints"
HISTORY_PATH = BASE_PATH + "/history"

labels_dict = {
  "0": "BASELINE",
  "1": "MASS BENIGN",
  "2": "MASS MALIGNANT",
  "3": "CALCIFICATION BENIGN",
  "4": "CALCIFICATION MALIGNANT"
}

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -q pyyaml h5py

# %%
# !pip install import_ipynb
# Out:
# Collecting import_ipynb
#   Downloading https://files.pythonhosted.org/packages/63/35/495e0021bfdcc924c7cdec4e9fbb87c88dd03b9b9b22419444dc370c8a45/import-ipynb-0.1.3.tar.gz
# Building wheels for collected packages: import-ipynb
#   Building wheel for import-ipynb (setup.py) ... done
#   Created wheel for import-ipynb: filename=import_ipynb-0.1.3-cp36-none-any.whl size=2976 sha256=99f4c03f3cbc89b0f67a3f56eecb1de161117b8f4fd70bdbd29429434c9ea911
#   Stored in directory: /root/.cache/pip/wheels/b4/7b/e9/a3a6e496115dffdb4e3085d0ae39ffe8a814eacc44bbf494b5
# Successfully built import-ipynb
# Installing collected packages: import-ipynb
# Successfully installed import-ipynb-0.1.3

# %%
# Get util functions
import import_ipynb
import drive.MyDrive.Petrocchi.util.preprocessing as preprocessing
import drive.MyDrive.Petrocchi.util.models as my_models
import drive.MyDrive.Petrocchi.util.visualization as visual
import drive.MyDrive.Petrocchi.util.SVM as svm
# Out:
# importing Jupyter notebook from /content/drive/MyDrive/Petrocchi/util/preprocessing.ipynb
# "load_images_and_lables" function loaded
# "preprocess_normalize_images" function loaded
# "deprocess_image_to_RGB" function loaded
# "deprocess_image" function loaded
# "datagen" class loaded
# "binary_subdivision" function loaded
# importing Jupyter notebook from /content/drive/MyDrive/Petrocchi/util/models.ipynb
# "tiny_net" CNN loaded
# "mammo_net" CNN loaded
# importing Jupyter notebook from /content/drive/MyDrive/Petrocchi/util/visualization.ipynb
# "plot_history" function loaded
# "plot_roc_curve" function loaded
# "plot_confusion_matrix" function loaded
# "generate_pattern" function loaded
# "display_filters_patterns" function loaded
# "display_features_maps" function loaded
# "generate_pattern_RGB" function loaded
# "display_filters_patterns" function loaded
# importing Jupyter notebook from /content/drive/MyDrive/Petrocchi/util/SVM.ipynb
# "create_feature_extractor" function loaded
# "extract_features" function loaded
# "train_svm_classifier" function loaded

# %% [markdown]
# ## Data Loading:

# %%
train_images, train_labels= preprocessing.load_images_and_lables(DATA_PATH + 'train_tensor.npy', DATA_PATH + 'train_labels.npy')
test_images, test_labels= preprocessing.load_images_and_lables(DATA_PATH + 'public_test_tensor.npy', DATA_PATH + 'public_test_labels.npy')

# Class Distribution
plt.hist(train_labels)
plt.title("Train Class Distribution")
plt.show()

unique, counts = np.unique(train_labels, return_counts=True)
plt.pie(counts, labels = ["BASELINE"," BENIGN","MASS MALIGNANT","CALCIFICATION BENIGN","CALCIFICATION MALIGNANT"])
plt.title('Train Class Distribution')
plt.show()

unique, counts = np.unique(test_labels, return_counts=True)
plt.pie(counts, labels = ["BASELINE","MASS BENIGN","MASS MALIGNANT","CALCIFICATION BENIGN","CALCIFICATION MALIGNANT"])
plt.title('Test Class Distribution')
plt.show()

# Plot an example
img_index = 5
plt.imshow(train_images[img_index,:,:],cmap = 'gray')
plt.title(labels_dict[str(train_labels[img_index])])
plt.show()

# %% [markdown]
# ## General Data Preprocessing:

# %% [markdown]
# Normalize and convert to RGB:

# %%
# I also need to convert back to numpy array using eval()
tf.compat.v1.disable_eager_execution()
sess = tf.compat.v1.Session()
with sess.as_default():
  print(train_images.shape)
  pp_train_images = tf.image.grayscale_to_rgb(tf.convert_to_tensor(preprocessing.preprocess_normalize_images(train_images, train_images.mean(), train_images.std()))).eval()
  print(pp_train_images.shape)

  print(test_images.shape)
  pp_test_images = tf.image.grayscale_to_rgb(tf.convert_to_tensor(preprocessing.preprocess_normalize_images(test_images, train_images.mean(), train_images.std()))).eval()
  print(pp_test_images.shape)
# Out:
# (5352, 150, 150)
# (5352, 150, 150, 3)
# (672, 150, 150)
# (672, 150, 150, 3)

# %% [markdown]
# Abnormalities-Baselines subdivision

# %%
# For reference
idx = 1
plt.imshow(preprocessing.deprocess_image_to_RGB(pp_train_images[idx]))
plt.title(labels_dict[str(train_labels[idx])])
plt.show()
plt.imshow(preprocessing.deprocess_image_to_RGB(pp_train_images[idx-1]))
plt.title(labels_dict[str(train_labels[idx-1])])
plt.show()

# %%
#Train
train_abnormalities = pp_train_images[1::2]
train_abnormalities_labels = train_labels[1::2]
train_baselines = pp_train_images[::2]

#Test
test_abnormalities = pp_test_images[1::2]
test_abnormalities_labels = test_labels[1::2]
test_baselines = pp_test_images[::2]

# Confirms that subdivision is good
idx = 0
plt.imshow(preprocessing.deprocess_image_to_RGB(train_abnormalities[idx]))
plt.title(labels_dict[str(train_abnormalities_labels[idx])])
plt.show()
plt.imshow(preprocessing.deprocess_image_to_RGB(train_baselines[idx]))
plt.title("Relative Baseline")
plt.show()

# %% [markdown]
# Test Augmentation:

# %%
# Test: show random augmented image
for batch in preprocessing.datagen.flow([train_abnormalities[0:1],train_baselines[0:1]], train_abnormalities_labels[0:1], batch_size=1):
    plt.title(labels_dict[str(batch[1][0])])
    print(batch[0][0].shape)
    plt.imshow(preprocessing.deprocess_image_to_RGB(batch[0][0][0][:,:,:]))
    plt.show()
    plt.imshow(preprocessing.deprocess_image_to_RGB(batch[0][1][0][:,:,:]))
    plt.title("Relative Baseline")
    plt.show()
    break
# Out:
# (1, 150, 150, 3)

# %% [markdown]
# Binary subdivision:

# %%
# 0: MASS, 1: CALCIFICATION
mc_train_images, mc_train_labels, mc_test_images, mc_test_labels = preprocessing.binary_subdivision( 
    [1,2], [3,4], train_abnormalities, train_abnormalities_labels, test_abnormalities, test_abnormalities_labels)  

print("Masses and Calcifications")
print(mc_train_images.shape)
print(mc_train_labels.shape)
print(mc_test_images.shape)
print(mc_test_labels.shape)

# Class Distribution
unique, counts = np.unique(mc_train_labels, return_counts=True)
plt.pie(counts, labels = ["MASS","CALCIFICATION"])
plt.title('Train Class Distribution')
plt.show()

unique, counts = np.unique(mc_test_labels, return_counts=True)
plt.pie(counts, labels = ["MASS","CALCIFICATION"])
plt.title('Test Class Distribution')
plt.show()
# Out:
# Masses and Calcifications
# (2676, 150, 150, 3)
# (2676,)
# (336, 150, 150, 3)
# (336,)

# %% [markdown]
# # Siamese Mass VS Calcification Classifiers

# %% [markdown]
# ### Split:

# %%
mc_train_images, mc_train_labels, mc_val_images, mc_val_labels, mc_val_baselines, mc_train_baselines = preprocessing.split_train_validation_baseline(mc_train_images, mc_train_labels, 0.2, train_baselines)

print(mc_train_images.shape)
print(mc_train_labels.shape)
print(mc_val_images.shape)
print(mc_val_labels.shape)
print(mc_train_baselines.shape)
print(mc_val_baselines.shape)

# Class Distribution
unique, counts = np.unique(mc_train_labels, return_counts=True)
plt.pie(counts, labels = ["MASS","CALCIFICATION"])
plt.title('Train Class Distribution')
plt.show()

unique, counts = np.unique(mc_val_labels, return_counts=True)
plt.pie(counts, labels = ["MASS","CALCIFICATION"])
plt.title('Validation Class Distribution')
plt.show()

idx = 22
plt.imshow(preprocessing.deprocess_image_to_RGB(mc_val_images[idx]))
plt.title("Abnormality")
plt.show()
plt.imshow(preprocessing.deprocess_image_to_RGB(mc_val_baselines[idx]))
plt.title("Relative Baseline")
plt.show()
# Out:
# (2140, 150, 150, 3)
# (2140,)
# (536, 150, 150, 3)
# (536,)
# (2140, 150, 150, 3)
# (536, 150, 150, 3)

# %% [markdown]
# ###General Parameters for training:

# %%
K.clear_session()

# %%
# Training parameters that are good for all models

# From ISMMS paper 32
# From Girona & Manchester paper 128
BATCH_SIZE = 107 # to have even batches 
STEPS_PER_EPOCH = len(mc_train_images) // BATCH_SIZE # 20
OPTIMIZER = tf.keras.optimizers.Adam(learning_rate=0.00001) # From Ecuador/Brazil paper
LOSS = 'binary_crossentropy'

# Large values ensures to not lose better weights 
MAX_EPOCHS = 1000 
PATIENCE = 50 

# Automatically restore best weights after early stopping
es_callback = tf.keras.callbacks.EarlyStopping(monitor = 'val_loss', patience = PATIENCE, restore_best_weights = True)

# %% [markdown]
# ### Siamese Features Difference:

# %%
from tensorflow.keras.applications import VGG16

TOP_K_FROZEN_LAYERS = 8
input_shape=(150, 150, 3)

# Define the tensors for the two input images
left_input = keras.Input(input_shape, name = "left_input")
right_input = keras.Input(input_shape, name = "right_input")

# Convolutional Neural Network
VGG16_base = VGG16(weights='imagenet',
                  include_top=False,
                  input_shape=input_shape)
VGG16_base.trainable = False

print("Frozen layers:")
for idx in range(TOP_K_FROZEN_LAYERS):
  print(VGG16_base.layers[idx].name)
  VGG16_base.layers[idx].trainable = False

VGG16_mc = models.Sequential(name = "VGG16_TL_mass_calcification")
VGG16_mc.add(VGG16_base)
VGG16_mc.add(layers.Flatten(name = "flatten"))

# Generate the encodings (feature vectors) for the two images
encoded_l = VGG16_mc(left_input)
encoded_r = VGG16_mc(right_input)

# Add a customized layer to compute the absolute difference between the encodings
L1_layer = layers.Lambda(lambda tensors:K.abs(tensors[0] - tensors[1]), name = "lambda")
L1_distance = L1_layer([encoded_l, encoded_r])

# Add a dense layer with a sigmoid unit to generate the similarity score
drop1 = layers.Dropout(0.2, name = "dropout_1")(L1_distance)
fc1 = layers.Dense(4096, activation='relu', name = "fully_connected_1")(drop1)
drop2 = layers.Dropout(0.2, name = "dropout_2")(fc1)
fc2 = layers.Dense(4096, activation='relu', name = "fully_connected_2")(drop2)
drop3 = layers.Dropout(0.1, name = "dropout_3")(fc2)
prediction = layers.Dense(1, activation='sigmoid', name = "fully_connected_out")(drop3)

# Connect the inputs with the outputs
siamese_mc_difference = Model(inputs=[left_input,right_input],outputs=prediction, name="siamese_mass_calcification_net")

siamese_mc_difference.summary()


siamese_mc_difference.compile(loss=LOSS,
              optimizer = OPTIMIZER,                   
              metrics=['accuracy'])

# Save weights when model improves (In case of disconnection)
cp_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=CHECKPOINT_PATH + "/siamese_mc_difference/checkpoint.ckpt", 
    verbose=1, 
    save_weights_only=True,
    save_best_only=True ) 

plot_model(siamese_mc_difference, show_shapes=True)
# Out:
# Frozen layers:
# input_1
# block1_conv1
# block1_conv2
# block1_pool
# block2_conv1
# block2_conv2
# block2_pool
# block3_conv1
# Model: "siamese_mass_calcification_net"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# left_input (InputLayer)         [(None, 150, 150, 3) 0
# __________________________________________________________________________________________________
# right_input (InputLayer)        [(None, 150, 150, 3) 0
# __________________________________________________________________________________________________
# VGG16_TL_mass_calcification (Se (None, 8192)         14714688    left_input[0][0]
#                                                                  right_input[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 8192)         0           VGG16_TL_mass_calcification[0][0]
#                                                                  VGG16_TL_mass_calcification[1][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 8192)         0           lambda[0][0]
# __________________________________________________________________________________________________
# fully_connected_1 (Dense)       (None, 4096)         33558528    dropout_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 4096)         0           fully_connected_1[0][0]
# __________________________________________________________________________________________________
# fully_connected_2 (Dense)       (None, 4096)         16781312    dropout_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 4096)         0           fully_connected_2[0][0]
# __________________________________________________________________________________________________
# fully_connected_out (Dense)     (None, 1)            4097        dropout_3[0][0]
# ==================================================================================================
# Total params: 65,058,625
# Trainable params: 50,343,937
# Non-trainable params: 14,714,688
# __________________________________________________________________________________________________

# %% [markdown]
# Training:

# %%
siamese_mc_difference_history = siamese_mc_difference.fit(preprocessing.datagen.flow([mc_train_images,mc_train_baselines], mc_train_labels, batch_size=BATCH_SIZE),
                       steps_per_epoch=STEPS_PER_EPOCH,  
                       epochs=MAX_EPOCHS, 
                       validation_data = ([mc_val_images,mc_val_baselines], mc_val_labels),
                       callbacks=[es_callback])#, cp_callback])
# Out:
# Epoch 1/1000
# 20/20 [==============================] - ETA: 0s - batch: 9.5000 - size: 107.0000 - loss: 0.6641 - accuracy: 0.5636
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:2325: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 20/20 [==============================] - 26s 688ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.6641 - accuracy: 0.5636 - val_loss: 0.6040 - val_accuracy: 0.7239
# Epoch 2/1000
# 20/20 [==============================] - 15s 767ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.5972 - accuracy: 0.7196 - val_loss: 0.5458 - val_accuracy: 0.7369
# Epoch 3/1000
# 20/20 [==============================] - 16s 791ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.5519 - accuracy: 0.7645 - val_loss: 0.4905 - val_accuracy: 0.7519
# Epoch 4/1000
# 20/20 [==============================] - 16s 797ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.5063 - accuracy: 0.8051 - val_loss: 0.4556 - val_accuracy: 0.7743
# Epoch 5/1000
# 20/20 [==============================] - 16s 801ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.4758 - accuracy: 0.8075 - val_loss: 0.4295 - val_accuracy: 0.7799
# Epoch 6/1000
# 20/20 [==============================] - 16s 803ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.4397 - accuracy: 0.8145 - val_loss: 0.4167 - val_accuracy: 0.7649
# Epoch 7/1000
# 20/20 [==============================] - 16s 809ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.4205 - accuracy: 0.8215 - val_loss: 0.3970 - val_accuracy: 0.7780
# Epoch 8/1000
# 20/20 [==============================] - 16s 811ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.4079 - accuracy: 0.8257 - val_loss: 0.3914 - val_accuracy: 0.7705
# Epoch 9/1000
# 20/20 [==============================] - 16s 807ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.3794 - accuracy: 0.8402 - val_loss: 0.3839 - val_accuracy: 0.7724
# Epoch 10/1000
# 20/20 [==============================] - 16s 803ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.3718 - accuracy: 0.8411 - val_loss: 0.3710 - val_accuracy: 0.7873
# Epoch 11/1000
# 20/20 [==============================] - 16s 816ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.3694 - accuracy: 0.8346 - val_loss: 0.3677 - val_accuracy: 0.7948
# Epoch 12/1000
# 20/20 [==============================] - 16s 823ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.3572 - accuracy: 0.8402 - val_loss: 0.3639 - val_accuracy: 0.8172
# Epoch 13/1000
# 20/20 [==============================] - 16s 838ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.3547 - accuracy: 0.8453 - val_loss: 0.3568 - val_accuracy: 0.8153
# Epoch 14/1000
# 20/20 [==============================] - 16s 823ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.3368 - accuracy: 0.8593 - val_loss: 0.3594 - val_accuracy: 0.8116
# Epoch 15/1000
# 20/20 [==============================] - 16s 817ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.3239 - accuracy: 0.8678 - val_loss: 0.3503 - val_accuracy: 0.8265
# Epoch 16/1000
# 20/20 [==============================] - 16s 828ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.3232 - accuracy: 0.8603 - val_loss: 0.3467 - val_accuracy: 0.8358
# Epoch 17/1000
# 20/20 [==============================] - 16s 825ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.3061 - accuracy: 0.8813 - val_loss: 0.3467 - val_accuracy: 0.8265
# Epoch 18/1000
# 20/20 [==============================] - 16s 828ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.2920 - accuracy: 0.8855 - val_loss: 0.3375 - val_accuracy: 0.8414
# Epoch 19/1000
# 20/20 [==============================] - 16s 825ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.3040 - accuracy: 0.8706 - val_loss: 0.3333 - val_accuracy: 0.8470
# Epoch 20/1000
# 20/20 [==============================] - 16s 826ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.2844 - accuracy: 0.8888 - val_loss: 0.3368 - val_accuracy: 0.8321
# Epoch 21/1000
# 20/20 [==============================] - 16s 817ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.2853 - accuracy: 0.8864 - val_loss: 0.3330 - val_accuracy: 0.8470
# Epoch 22/1000
# 20/20 [==============================] - 16s 825ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.2872 - accuracy: 0.8804 - val_loss: 0.3309 - val_accuracy: 0.8489
# Epoch 23/1000
# 20/20 [==============================] - 16s 826ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.2890 - accuracy: 0.8752 - val_loss: 0.3283 - val_accuracy: 0.8451
# Epoch 24/1000
# 20/20 [==============================] - 16s 823ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.2838 - accuracy: 0.8804 - val_loss: 0.3308 - val_accuracy: 0.8451
# Epoch 25/1000
# 20/20 [==============================] - 16s 811ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.2748 - accuracy: 0.8916 - val_loss: 0.3328 - val_accuracy: 0.8377
# Epoch 26/1000
# 20/20 [==============================] - 16s 821ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.2596 - accuracy: 0.8935 - val_loss: 0.3256 - val_accuracy: 0.8451
# Epoch 27/1000
# 20/20 [==============================] - 16s 826ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.2685 - accuracy: 0.8925 - val_loss: 0.3252 - val_accuracy: 0.8396
# Epoch 28/1000
# 20/20 [==============================] - 16s 826ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.2608 - accuracy: 0.8958 - val_loss: 0.3243 - val_accuracy: 0.8507
# Epoch 29/1000
# 20/20 [==============================] - 16s 822ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.2619 - accuracy: 0.8967 - val_loss: 0.3428 - val_accuracy: 0.8284
# Epoch 30/1000
# 20/20 [==============================] - 16s 816ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.2490 - accuracy: 0.9051 - val_loss: 0.3292 - val_accuracy: 0.8340
# Epoch 31/1000
# 20/20 [==============================] - 16s 820ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.2555 - accuracy: 0.8963 - val_loss: 0.3223 - val_accuracy: 0.8563
# Epoch 32/1000
# 20/20 [==============================] - 16s 816ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.2516 - accuracy: 0.8995 - val_loss: 0.3325 - val_accuracy: 0.8396
# Epoch 33/1000
# 20/20 [==============================] - 16s 823ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.2433 - accuracy: 0.9028 - val_loss: 0.3243 - val_accuracy: 0.8526
# Epoch 34/1000
# 20/20 [==============================] - 16s 829ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.2488 - accuracy: 0.9033 - val_loss: 0.3476 - val_accuracy: 0.8246
# Epoch 35/1000
# 20/20 [==============================] - 16s 820ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.2464 - accuracy: 0.9051 - val_loss: 0.3230 - val_accuracy: 0.8526
# Epoch 36/1000
# 20/20 [==============================] - 16s 822ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.2504 - accuracy: 0.8991 - val_loss: 0.3201 - val_accuracy: 0.8470
# Epoch 37/1000
# 20/20 [==============================] - 16s 819ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.2291 - accuracy: 0.9173 - val_loss: 0.3229 - val_accuracy: 0.8414
# Epoch 38/1000
# 20/20 [==============================] - 16s 823ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.2433 - accuracy: 0.9009 - val_loss: 0.3235 - val_accuracy: 0.8489
# Epoch 39/1000
# 20/20 [==============================] - 16s 818ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.2426 - accuracy: 0.8981 - val_loss: 0.3341 - val_accuracy: 0.8340
# Epoch 40/1000
# 20/20 [==============================] - 16s 812ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.2225 - accuracy: 0.9121 - val_loss: 0.3196 - val_accuracy: 0.8526
# Epoch 41/1000
# 20/20 [==============================] - 16s 814ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.2290 - accuracy: 0.9019 - val_loss: 0.3194 - val_accuracy: 0.8451
# Epoch 42/1000
# 20/20 [==============================] - 16s 814ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.2323 - accuracy: 0.9079 - val_loss: 0.3220 - val_accuracy: 0.8451
# Epoch 43/1000
# 20/20 [==============================] - 16s 815ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.2184 - accuracy: 0.9164 - val_loss: 0.3261 - val_accuracy: 0.8470
# Epoch 44/1000
# 20/20 [==============================] - 16s 822ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.2264 - accuracy: 0.9164 - val_loss: 0.3206 - val_accuracy: 0.8470
# Epoch 45/1000
# 20/20 [==============================] - 16s 812ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.2172 - accuracy: 0.9159 - val_loss: 0.3218 - val_accuracy: 0.8470
# Epoch 46/1000
# 20/20 [==============================] - 16s 821ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.2030 - accuracy: 0.9196 - val_loss: 0.3250 - val_accuracy: 0.8396
# Epoch 47/1000
# 20/20 [==============================] - 16s 806ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.2073 - accuracy: 0.9243 - val_loss: 0.3250 - val_accuracy: 0.8396
# Epoch 48/1000
# 20/20 [==============================] - 16s 824ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.2058 - accuracy: 0.9220 - val_loss: 0.3230 - val_accuracy: 0.8470
# Epoch 49/1000
# 20/20 [==============================] - 16s 821ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.2215 - accuracy: 0.9075 - val_loss: 0.3666 - val_accuracy: 0.8209
# Epoch 50/1000
# 20/20 [==============================] - 16s 818ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.2219 - accuracy: 0.9093 - val_loss: 0.3248 - val_accuracy: 0.8451
# Epoch 51/1000
# 20/20 [==============================] - 16s 814ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.2121 - accuracy: 0.9126 - val_loss: 0.3215 - val_accuracy: 0.8414
# Epoch 52/1000
# 20/20 [==============================] - 16s 818ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.2156 - accuracy: 0.9126 - val_loss: 0.3271 - val_accuracy: 0.8414
# Epoch 53/1000
# 20/20 [==============================] - 16s 821ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1944 - accuracy: 0.9248 - val_loss: 0.3262 - val_accuracy: 0.8451
# Epoch 54/1000
# 20/20 [==============================] - 16s 823ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.2052 - accuracy: 0.9276 - val_loss: 0.3445 - val_accuracy: 0.8377
# Epoch 55/1000
# 20/20 [==============================] - 16s 814ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1983 - accuracy: 0.9187 - val_loss: 0.3474 - val_accuracy: 0.8321
# Epoch 56/1000
# 20/20 [==============================] - 16s 835ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.2032 - accuracy: 0.9257 - val_loss: 0.3296 - val_accuracy: 0.8433
# Epoch 57/1000
# 20/20 [==============================] - 16s 819ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1974 - accuracy: 0.9182 - val_loss: 0.3252 - val_accuracy: 0.8377
# Epoch 58/1000
# 20/20 [==============================] - 16s 827ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1926 - accuracy: 0.9304 - val_loss: 0.3285 - val_accuracy: 0.8414
# Epoch 59/1000
# 20/20 [==============================] - 16s 815ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1922 - accuracy: 0.9304 - val_loss: 0.3545 - val_accuracy: 0.8377
# Epoch 60/1000
# 20/20 [==============================] - 16s 817ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.2081 - accuracy: 0.9112 - val_loss: 0.3281 - val_accuracy: 0.8377
# Epoch 61/1000
# 20/20 [==============================] - 16s 810ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1946 - accuracy: 0.9243 - val_loss: 0.3389 - val_accuracy: 0.8414
# Epoch 62/1000
# 20/20 [==============================] - 16s 805ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1934 - accuracy: 0.9220 - val_loss: 0.3331 - val_accuracy: 0.8414
# Epoch 63/1000
# 20/20 [==============================] - 16s 819ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1911 - accuracy: 0.9271 - val_loss: 0.3270 - val_accuracy: 0.8358
# Epoch 64/1000
# 20/20 [==============================] - 16s 814ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1807 - accuracy: 0.9299 - val_loss: 0.3278 - val_accuracy: 0.8470
# Epoch 65/1000
# 20/20 [==============================] - 16s 815ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1923 - accuracy: 0.9243 - val_loss: 0.3339 - val_accuracy: 0.8470
# Epoch 66/1000
# 20/20 [==============================] - 16s 807ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1699 - accuracy: 0.9379 - val_loss: 0.3317 - val_accuracy: 0.8451
# Epoch 67/1000
# 20/20 [==============================] - 16s 804ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1725 - accuracy: 0.9364 - val_loss: 0.3578 - val_accuracy: 0.8358
# Epoch 68/1000
# 20/20 [==============================] - 16s 814ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1745 - accuracy: 0.9308 - val_loss: 0.3354 - val_accuracy: 0.8396
# Epoch 69/1000
# 20/20 [==============================] - 16s 805ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1867 - accuracy: 0.9192 - val_loss: 0.3353 - val_accuracy: 0.8396
# Epoch 70/1000
# 20/20 [==============================] - 16s 818ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1836 - accuracy: 0.9257 - val_loss: 0.3305 - val_accuracy: 0.8433
# Epoch 71/1000
# 20/20 [==============================] - 16s 801ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1707 - accuracy: 0.9294 - val_loss: 0.3293 - val_accuracy: 0.8358
# Epoch 72/1000
# 20/20 [==============================] - 16s 815ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1725 - accuracy: 0.9374 - val_loss: 0.3511 - val_accuracy: 0.8358
# Epoch 73/1000
# 20/20 [==============================] - 16s 810ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1734 - accuracy: 0.9304 - val_loss: 0.3347 - val_accuracy: 0.8396
# Epoch 74/1000
# 20/20 [==============================] - 16s 810ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1684 - accuracy: 0.9355 - val_loss: 0.3355 - val_accuracy: 0.8377
# Epoch 75/1000
# 20/20 [==============================] - 16s 807ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1810 - accuracy: 0.9336 - val_loss: 0.3339 - val_accuracy: 0.8377
# Epoch 76/1000
# 20/20 [==============================] - 16s 795ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1831 - accuracy: 0.9271 - val_loss: 0.3486 - val_accuracy: 0.8414
# Epoch 77/1000
# 20/20 [==============================] - 16s 803ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1792 - accuracy: 0.9304 - val_loss: 0.3318 - val_accuracy: 0.8470
# Epoch 78/1000
# 20/20 [==============================] - 16s 804ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1720 - accuracy: 0.9360 - val_loss: 0.3392 - val_accuracy: 0.8433
# Epoch 79/1000
# 20/20 [==============================] - 16s 800ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1800 - accuracy: 0.9238 - val_loss: 0.3395 - val_accuracy: 0.8396
# Epoch 80/1000
# 20/20 [==============================] - 16s 804ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1641 - accuracy: 0.9411 - val_loss: 0.3400 - val_accuracy: 0.8451
# Epoch 81/1000
# 20/20 [==============================] - 16s 800ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1703 - accuracy: 0.9364 - val_loss: 0.3362 - val_accuracy: 0.8396
# Epoch 82/1000
# 20/20 [==============================] - 16s 803ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1625 - accuracy: 0.9435 - val_loss: 0.3417 - val_accuracy: 0.8414
# Epoch 83/1000
# 20/20 [==============================] - 16s 811ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1744 - accuracy: 0.9304 - val_loss: 0.3403 - val_accuracy: 0.8358
# Epoch 84/1000
# 20/20 [==============================] - 16s 814ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1683 - accuracy: 0.9350 - val_loss: 0.3768 - val_accuracy: 0.8246
# Epoch 85/1000
# 20/20 [==============================] - 16s 800ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1661 - accuracy: 0.9383 - val_loss: 0.3429 - val_accuracy: 0.8451
# Epoch 86/1000
# 20/20 [==============================] - 16s 809ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1636 - accuracy: 0.9388 - val_loss: 0.3532 - val_accuracy: 0.8340
# Epoch 87/1000
# 20/20 [==============================] - 16s 803ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1522 - accuracy: 0.9449 - val_loss: 0.3473 - val_accuracy: 0.8451
# Epoch 88/1000
# 20/20 [==============================] - 16s 806ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1487 - accuracy: 0.9500 - val_loss: 0.3440 - val_accuracy: 0.8414
# Epoch 89/1000
# 20/20 [==============================] - 16s 802ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1593 - accuracy: 0.9425 - val_loss: 0.3478 - val_accuracy: 0.8340
# Epoch 90/1000
# 20/20 [==============================] - 16s 806ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1481 - accuracy: 0.9509 - val_loss: 0.3463 - val_accuracy: 0.8433
# Epoch 91/1000
# 20/20 [==============================] - 16s 805ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1598 - accuracy: 0.9430 - val_loss: 0.3512 - val_accuracy: 0.8340

# %%
# Save and load history
with open(HISTORY_PATH + '/siamese_mc_difference_history', 'wb') as file_pi:
        pickle.dump(siamese_mc_difference_history.history, file_pi)

siamese_mc_difference_history = pickle.load(open(HISTORY_PATH + '/siamese_mc_difference_history', "rb"))

visual.plot_history(siamese_mc_difference_history)

# %%
train_loss, train_acc = siamese_mc_difference.evaluate([mc_train_images,mc_train_baselines], mc_train_labels)
print(f"Accuracy on train set: {round(train_acc*100, 2)}% \nLoss on train set: {round(train_loss,4)}")
val_loss, val_acc = siamese_mc_difference.evaluate([mc_val_images,mc_val_baselines], mc_val_labels)
print(f"Accuracy on validation set: {round(val_acc*100, 2)}% \nLoss on validation set: {round(val_loss,4)}")
test_loss, test_acc = siamese_mc_difference.evaluate([mc_test_images,test_baselines], mc_test_labels)
print(f"Accuracy on test set: {round(test_acc*100, 2)}% \nLoss on test set: {round(test_loss,4)}")
# Out:
# Accuracy on train set: 91.87%
# Loss on train set: 0.2035
# Accuracy on validation set: 84.51%
# Loss on validation set: 0.3712
# Accuracy on test set: 82.44%
# Loss on test set: 0.4357

# %% [markdown]
# Load best weights and save:

# %%
# If disconnection occur best weights so far are restored 

#best = tf.train.latest_checkpoint(CHECKPOINT_PATH + "/siamese_mc_difference/")
#siamese_mc_difference.load_weights(best)

# %%
if not os.path.exists(MODELS_PATH):
  os.makedirs(MODELS_PATH)
siamese_mc_difference.save(os.path.join(MODELS_PATH,'siamese_mc_difference.h5'))

# %% [markdown]
# ### Siamese Features Concatenated:

# %%
from tensorflow.keras.applications import VGG16

TOP_K_FROZEN_LAYERS = 8
input_shape=(150, 150, 3)

# Define the tensors for the two input images
left_input = keras.Input(input_shape, name="left_input")
right_input = keras.Input(input_shape, name="right_input")

# Convolutional Neural Network
VGG16_base = VGG16(weights='imagenet',
                  include_top=False,
                  input_shape=input_shape)
VGG16_base.trainable = False

print("Frozen layers:")
for idx in range(TOP_K_FROZEN_LAYERS):
  print(VGG16_base.layers[idx].name)
  VGG16_base.layers[idx].trainable = False

VGG16_mc = models.Sequential(name = "VGG16_TL_mass_calcification")
VGG16_mc.add(VGG16_base)
VGG16_mc.add(layers.Flatten(name = "flatten"))

# Generate the encodings (feature vectors) for the two images
encoded_l = VGG16_mc(left_input)
encoded_r = VGG16_mc(right_input)

# Concatenates the layers 
juxtapose_layer = layers.Concatenate()([encoded_l, encoded_r])

# Add a dense layer with a sigmoid unit to generate the similarity score
drop1 = layers.Dropout(0.2, name = "dropout_1")(juxtapose_layer)
fc1 = layers.Dense(4096, activation='relu', name = "fully_connected_1")(drop1)
drop2 = layers.Dropout(0.2, name = "dropout_2")(fc1)
fc2 = layers.Dense(4096, activation='relu', name = "fully_connected_2")(drop2)
drop3 = layers.Dropout(0.1, name = "dropout_3")(fc2)
prediction = layers.Dense(1, activation='sigmoid', name = "fully_connected_out")(drop3)

# Connect the inputs with the outputs
siamese_mc_concat = Model(inputs=[left_input,right_input],outputs=prediction, name="siamese_mass_calcification_net")

siamese_mc_concat.summary()


siamese_mc_concat.compile(loss=LOSS,
              optimizer = OPTIMIZER,                   
              metrics=['accuracy'])

# Save weights when model improves (In case of disconnection)
cp_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=CHECKPOINT_PATH + "/siamese_mc_concat/checkpoint.ckpt", 
    verbose=1, 
    save_weights_only=True,
    save_best_only=True )
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 0s 0us/step
# Frozen layers:
# input_1
# block1_conv1
# block1_conv2
# block1_pool
# block2_conv1
# block2_conv2
# block2_pool
# block3_conv1
# Model: "siamese_mass_calcification_net"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# left_input (InputLayer)         [(None, 150, 150, 3) 0
# __________________________________________________________________________________________________
# right_input (InputLayer)        [(None, 150, 150, 3) 0
# __________________________________________________________________________________________________
# VGG16_TL_mass_calcification (Se (None, 8192)         14714688    left_input[0][0]
#                                                                  right_input[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 16384)        0           VGG16_TL_mass_calcification[0][0]
#                                                                  VGG16_TL_mass_calcification[1][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 16384)        0           concatenate[0][0]
# __________________________________________________________________________________________________
# fully_connected_1 (Dense)       (None, 4096)         67112960    dropout_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 4096)         0           fully_connected_1[0][0]
# __________________________________________________________________________________________________
# fully_connected_2 (Dense)       (None, 4096)         16781312    dropout_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 4096)         0           fully_connected_2[0][0]
# __________________________________________________________________________________________________
# fully_connected_out (Dense)     (None, 1)            4097        dropout_3[0][0]
# ==================================================================================================
# Total params: 98,613,057
# Trainable params: 83,898,369
# Non-trainable params: 14,714,688
# __________________________________________________________________________________________________

# %% [markdown]
# Training:

# %%
siamese_mc_concat_history = siamese_mc_concat.fit(preprocessing.datagen.flow([mc_train_images,mc_train_baselines], mc_train_labels, batch_size=BATCH_SIZE),
                       steps_per_epoch=STEPS_PER_EPOCH,  
                       epochs=MAX_EPOCHS, 
                       validation_data = ([mc_val_images,mc_val_baselines], mc_val_labels),
                       callbacks=[es_callback])#, cp_callback])
# Out:
# Epoch 1/1000
# 20/20 [==============================] - ETA: 0s - batch: 9.5000 - size: 107.0000 - loss: 0.6334 - accuracy: 0.6332
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:2325: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 20/20 [==============================] - 24s 566ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.6334 - accuracy: 0.6332 - val_loss: 0.4919 - val_accuracy: 0.8209
# Epoch 2/1000
# 20/20 [==============================] - 13s 662ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.5227 - accuracy: 0.7617 - val_loss: 0.4607 - val_accuracy: 0.7593
# Epoch 3/1000
# 20/20 [==============================] - 13s 682ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.4373 - accuracy: 0.8210 - val_loss: 0.3613 - val_accuracy: 0.8190
# Epoch 4/1000
# 20/20 [==============================] - 13s 676ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.4008 - accuracy: 0.8290 - val_loss: 0.3730 - val_accuracy: 0.8004
# Epoch 5/1000
# 20/20 [==============================] - 14s 740ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.3692 - accuracy: 0.8458 - val_loss: 0.3065 - val_accuracy: 0.8377
# Epoch 6/1000
# 20/20 [==============================] - 13s 686ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.3382 - accuracy: 0.8556 - val_loss: 0.2902 - val_accuracy: 0.8433
# Epoch 7/1000
# 20/20 [==============================] - 14s 691ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.3239 - accuracy: 0.8706 - val_loss: 0.2723 - val_accuracy: 0.8545
# Epoch 8/1000
# 20/20 [==============================] - 14s 688ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.3071 - accuracy: 0.8785 - val_loss: 0.3030 - val_accuracy: 0.8433
# Epoch 9/1000
# 20/20 [==============================] - 14s 689ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.3032 - accuracy: 0.8724 - val_loss: 0.2629 - val_accuracy: 0.8601
# Epoch 10/1000
# 20/20 [==============================] - 14s 693ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.2973 - accuracy: 0.8785 - val_loss: 0.2604 - val_accuracy: 0.8582
# Epoch 11/1000
# 20/20 [==============================] - 14s 692ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.2813 - accuracy: 0.8771 - val_loss: 0.3137 - val_accuracy: 0.8470
# Epoch 12/1000
# 20/20 [==============================] - 14s 690ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.2742 - accuracy: 0.8921 - val_loss: 0.2876 - val_accuracy: 0.8526
# Epoch 13/1000
# 20/20 [==============================] - 14s 693ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.2714 - accuracy: 0.8879 - val_loss: 0.2726 - val_accuracy: 0.8619
# Epoch 14/1000
# 20/20 [==============================] - 14s 694ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.2544 - accuracy: 0.9033 - val_loss: 0.2662 - val_accuracy: 0.8563
# Epoch 15/1000
# 20/20 [==============================] - 14s 693ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.2486 - accuracy: 0.9033 - val_loss: 0.2838 - val_accuracy: 0.8526
# Epoch 16/1000
# 20/20 [==============================] - 14s 697ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.2529 - accuracy: 0.9019 - val_loss: 0.2510 - val_accuracy: 0.8657
# Epoch 17/1000
# 20/20 [==============================] - 14s 696ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.2295 - accuracy: 0.9103 - val_loss: 0.2888 - val_accuracy: 0.8489
# Epoch 18/1000
# 20/20 [==============================] - 14s 698ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.2436 - accuracy: 0.9033 - val_loss: 0.2832 - val_accuracy: 0.8526
# Epoch 19/1000
# 20/20 [==============================] - 14s 705ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.2316 - accuracy: 0.9084 - val_loss: 0.2554 - val_accuracy: 0.8713
# Epoch 20/1000
# 20/20 [==============================] - 14s 704ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.2297 - accuracy: 0.9061 - val_loss: 0.2745 - val_accuracy: 0.8619
# Epoch 21/1000
# 20/20 [==============================] - 14s 699ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.2268 - accuracy: 0.9098 - val_loss: 0.2557 - val_accuracy: 0.8694
# Epoch 22/1000
# 20/20 [==============================] - 14s 699ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.2197 - accuracy: 0.9089 - val_loss: 0.2659 - val_accuracy: 0.8694
# Epoch 23/1000
# 20/20 [==============================] - 14s 699ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.2165 - accuracy: 0.9140 - val_loss: 0.2655 - val_accuracy: 0.8657
# Epoch 24/1000
# 20/20 [==============================] - 14s 709ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1995 - accuracy: 0.9266 - val_loss: 0.2692 - val_accuracy: 0.8675
# Epoch 25/1000
# 20/20 [==============================] - 14s 703ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.2195 - accuracy: 0.9121 - val_loss: 0.2554 - val_accuracy: 0.8769
# Epoch 26/1000
# 20/20 [==============================] - 14s 700ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.2123 - accuracy: 0.9168 - val_loss: 0.2575 - val_accuracy: 0.8769
# Epoch 27/1000
# 20/20 [==============================] - 14s 700ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.2022 - accuracy: 0.9229 - val_loss: 0.2620 - val_accuracy: 0.8713
# Epoch 28/1000
# 20/20 [==============================] - 14s 702ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.2005 - accuracy: 0.9224 - val_loss: 0.2606 - val_accuracy: 0.8694
# Epoch 29/1000
# 20/20 [==============================] - 14s 697ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.2000 - accuracy: 0.9196 - val_loss: 0.2584 - val_accuracy: 0.8787
# Epoch 30/1000
# 20/20 [==============================] - 14s 710ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1830 - accuracy: 0.9290 - val_loss: 0.2637 - val_accuracy: 0.8713
# Epoch 31/1000
# 20/20 [==============================] - 14s 718ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.2039 - accuracy: 0.9164 - val_loss: 0.2566 - val_accuracy: 0.8825
# Epoch 32/1000
# 20/20 [==============================] - 14s 726ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1856 - accuracy: 0.9318 - val_loss: 0.2613 - val_accuracy: 0.8731
# Epoch 33/1000
# 20/20 [==============================] - 14s 721ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1867 - accuracy: 0.9290 - val_loss: 0.2730 - val_accuracy: 0.8694
# Epoch 34/1000
# 20/20 [==============================] - 14s 705ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1867 - accuracy: 0.9318 - val_loss: 0.3130 - val_accuracy: 0.8619
# Epoch 35/1000
# 20/20 [==============================] - 14s 700ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1812 - accuracy: 0.9322 - val_loss: 0.2603 - val_accuracy: 0.8787
# Epoch 36/1000
# 20/20 [==============================] - 14s 699ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1842 - accuracy: 0.9196 - val_loss: 0.2711 - val_accuracy: 0.8843
# Epoch 37/1000
# 20/20 [==============================] - 14s 703ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1803 - accuracy: 0.9234 - val_loss: 0.2650 - val_accuracy: 0.8787
# Epoch 38/1000
# 20/20 [==============================] - 14s 701ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1755 - accuracy: 0.9360 - val_loss: 0.2856 - val_accuracy: 0.8675
# Epoch 39/1000
# 20/20 [==============================] - 14s 700ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1706 - accuracy: 0.9332 - val_loss: 0.3004 - val_accuracy: 0.8638
# Epoch 40/1000
# 20/20 [==============================] - 14s 702ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1681 - accuracy: 0.9322 - val_loss: 0.2766 - val_accuracy: 0.8769
# Epoch 41/1000
# 20/20 [==============================] - 14s 705ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1714 - accuracy: 0.9327 - val_loss: 0.2688 - val_accuracy: 0.8787
# Epoch 42/1000
# 20/20 [==============================] - 14s 711ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1587 - accuracy: 0.9421 - val_loss: 0.2665 - val_accuracy: 0.8787
# Epoch 43/1000
# 20/20 [==============================] - 14s 706ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1684 - accuracy: 0.9332 - val_loss: 0.3149 - val_accuracy: 0.8619
# Epoch 44/1000
# 20/20 [==============================] - 14s 713ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1590 - accuracy: 0.9402 - val_loss: 0.2908 - val_accuracy: 0.8675
# Epoch 45/1000
# 20/20 [==============================] - 14s 703ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1526 - accuracy: 0.9402 - val_loss: 0.3176 - val_accuracy: 0.8638
# Epoch 46/1000
# 20/20 [==============================] - 14s 734ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1573 - accuracy: 0.9411 - val_loss: 0.2743 - val_accuracy: 0.8806
# Epoch 47/1000
# 20/20 [==============================] - 14s 710ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1443 - accuracy: 0.9425 - val_loss: 0.2782 - val_accuracy: 0.8787
# Epoch 48/1000
# 20/20 [==============================] - 14s 707ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1571 - accuracy: 0.9360 - val_loss: 0.2759 - val_accuracy: 0.8769
# Epoch 49/1000
# 20/20 [==============================] - 14s 705ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1631 - accuracy: 0.9374 - val_loss: 0.2844 - val_accuracy: 0.8750
# Epoch 50/1000
# 20/20 [==============================] - 14s 703ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1410 - accuracy: 0.9491 - val_loss: 0.2995 - val_accuracy: 0.8713
# Epoch 51/1000
# 20/20 [==============================] - 14s 702ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1412 - accuracy: 0.9491 - val_loss: 0.3105 - val_accuracy: 0.8694
# Epoch 52/1000
# 20/20 [==============================] - 14s 700ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1578 - accuracy: 0.9350 - val_loss: 0.2764 - val_accuracy: 0.8787
# Epoch 53/1000
# 20/20 [==============================] - 14s 702ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1533 - accuracy: 0.9393 - val_loss: 0.2798 - val_accuracy: 0.8787
# Epoch 54/1000
# 20/20 [==============================] - 14s 723ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1481 - accuracy: 0.9411 - val_loss: 0.2864 - val_accuracy: 0.8769
# Epoch 55/1000
# 20/20 [==============================] - 14s 712ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1313 - accuracy: 0.9509 - val_loss: 0.2784 - val_accuracy: 0.8787
# Epoch 56/1000
# 20/20 [==============================] - 14s 706ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1384 - accuracy: 0.9481 - val_loss: 0.2890 - val_accuracy: 0.8769
# Epoch 57/1000
# 20/20 [==============================] - 14s 717ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1257 - accuracy: 0.9523 - val_loss: 0.2974 - val_accuracy: 0.8769
# Epoch 58/1000
# 20/20 [==============================] - 14s 724ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1368 - accuracy: 0.9439 - val_loss: 0.2882 - val_accuracy: 0.8769
# Epoch 59/1000
# 20/20 [==============================] - 14s 715ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1428 - accuracy: 0.9523 - val_loss: 0.3260 - val_accuracy: 0.8619
# Epoch 60/1000
# 20/20 [==============================] - 14s 715ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1237 - accuracy: 0.9500 - val_loss: 0.2890 - val_accuracy: 0.8731
# Epoch 61/1000
# 20/20 [==============================] - 14s 702ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1267 - accuracy: 0.9491 - val_loss: 0.3105 - val_accuracy: 0.8657
# Epoch 62/1000
# 20/20 [==============================] - 14s 709ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1264 - accuracy: 0.9477 - val_loss: 0.3201 - val_accuracy: 0.8675
# Epoch 63/1000
# 20/20 [==============================] - 14s 703ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1311 - accuracy: 0.9533 - val_loss: 0.2976 - val_accuracy: 0.8806
# Epoch 64/1000
# 20/20 [==============================] - 14s 703ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1329 - accuracy: 0.9514 - val_loss: 0.2976 - val_accuracy: 0.8769
# Epoch 65/1000
# 20/20 [==============================] - 14s 701ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1296 - accuracy: 0.9458 - val_loss: 0.2950 - val_accuracy: 0.8787
# Epoch 66/1000
# 20/20 [==============================] - 14s 715ms/step - batch: 9.5000 - size: 107.0000 - loss: 0.1363 - accuracy: 0.9458 - val_loss: 0.3364 - val_accuracy: 0.8601

# %%
# Save and load history
with open(HISTORY_PATH + '/siamese_mc_concat_history', 'wb') as file_pi:
        pickle.dump(siamese_mc_concat_history.history, file_pi)

siamese_mc_concat_history = pickle.load(open(HISTORY_PATH + '/siamese_mc_concat_history', "rb"))

visual.plot_history(siamese_mc_concat_history)

# %%
train_loss, train_acc = siamese_mc_concat.evaluate([mc_train_images,mc_train_baselines], mc_train_labels)
print(f"Accuracy on train set: {round(train_acc*100, 2)}% \nLoss on train set: {round(train_loss,4)}")
val_loss, val_acc = siamese_mc_concat.evaluate([mc_val_images,mc_val_baselines], mc_val_labels)
print(f"Accuracy on validation set: {round(val_acc*100, 2)}% \nLoss on validation set: {round(val_loss,4)}")
test_loss, test_acc = siamese_mc_concat.evaluate([mc_test_images,test_baselines], mc_test_labels)
print(f"Accuracy on test set: {round(test_acc*100, 2)}% \nLoss on test set: {round(test_loss,4)}")
# Out:
# Accuracy on train set: 91.59%
# Loss on train set: 0.2078
# Accuracy on validation set: 86.57%
# Loss on validation set: 0.2918
# Accuracy on test set: 86.01%
# Loss on test set: 0.3053

# %% [markdown]
# Load best weights and save:

# %%
# If disconnection occur best weights so far are restored 

#best = tf.train.latest_checkpoint(CHECKPOINT_PATH + "/siamese_mc_concat/")
#siamese_mc_concat.load_weights(best)

# %%
if not os.path.exists(MODELS_PATH):
  os.makedirs(MODELS_PATH)
siamese_mc_concat.save(os.path.join(MODELS_PATH,'siamese_mc_concat.h5'))

# %% [markdown]
# # Compare Results

# %% [markdown]
# ##Scoring:

# %%
# Siamese Difference
test_loss, test_acc = siamese_mc_difference.evaluate([mc_test_images,test_baselines], mc_test_labels)
print("Siamese Difference")
print(f"Accuracy on test set: {round(test_acc*100, 2)}% \nLoss on test set: {round(test_loss,4)}")

siamese_mc_difference_test_predictions = siamese_mc_difference.predict([mc_test_images,test_baselines])
binary_siamese_mc_difference_test_predictions = siamese_mc_difference_test_predictions.round()
visual.plot_confusion_matrix(mc_test_labels, binary_siamese_mc_difference_test_predictions, ["MASS", "CALCIFICATION"])

# Siamese Concatenation
test_loss, test_acc = siamese_mc_concat.evaluate([mc_test_images,test_baselines], mc_test_labels)
print("Siamese Concatenation")
print(f"Accuracy on test set: {round(test_acc*100, 2)}% \nLoss on test set: {round(test_loss,4)}")

siamese_mc_concat_test_predictions = siamese_mc_concat.predict([mc_test_images,test_baselines])
binary_siamese_mc_concat_test_predictions = siamese_mc_concat_test_predictions.round()
visual.plot_confusion_matrix(mc_test_labels, binary_siamese_mc_concat_test_predictions, ["MASS", "CALCIFICATION"])

models_predictions = [siamese_mc_difference_test_predictions,
                      siamese_mc_concat_test_predictions]

# ROC
visual.plot_roc_curve(mc_test_labels, models_predictions, ["Siamese Difference", "Siamese Concat"])
# Out:
# Siamese Difference
# Accuracy on test set: 82.44%
# Loss on test set: 0.4357
# Siamese Concatenation
# Accuracy on test set: 86.31%
# Loss on test set: 0.3014

# %% [markdown]
# Author: **Stefano Petrocchi**
